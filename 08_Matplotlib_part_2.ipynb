# %%
import matplotlib.pyplot

# %%
a=[10,20,30,40]  # show the x - axis
b=[80,160,200,500] # show the Y - axis
matplotlib.pyplot.plot(a,b) # mean by (a,b)
matplotlib.pyplot.show()

# %% [markdown]
# # save fig
# ### and also yee kha pe work karta hai
# ### show ke baad or show ke phale
# ### Focus on it

# %%
a=[10,20,30,40]
b=[80,160,200,500] 
matplotlib.pyplot.plot(a,b)
matplotlib.pyplot.show()
matplotlib.pyplot.savefig("new_xyz.png")

# %%
import os
cmd = 'ls -l'
os.system(cmd)

# check the new_xyz.png is not display anything because of yee show se phale hai 
# kuch write nhi huva xyz.png me

import IPython.display as display
from PIL import Image
display.display(Image.open('new_xyz.png'))
# Out:
# total 13112
# -rw-r--r--   1 sandeepmakwana  staff     1026 Mar 23  2023 01_importend_topics.txt
# -rw-r--r--@  1 sandeepmakwana  staff    11377 Nov 21 19:26 02_Vector_Operations.ipynb
# -rw-r--r--@  1 sandeepmakwana  staff    19625 Nov 22 20:00 03_Numpy_operations_part_1.ipynb
# -rw-r--r--@  1 sandeepmakwana  staff     7181 Nov 23 08:47 04_Numpy_operations_part_2.ipynb
# -rw-r--r--@  1 sandeepmakwana  staff    12951 Nov 23 09:01 05_Matrix_opreations_part_3.ipynb
# -rw-r--r--@  1 sandeepmakwana  staff    17431 Nov 23 19:39 06_matrix_operations_part_5.ipynb
# -rw-r--r--@  1 sandeepmakwana  staff   762722 Nov 23 20:10 07_Matplotlib_part_1.ipynb
# -rw-r--r--@  1 sandeepmakwana  staff   589739 Nov 30 15:50 08_Matplotlib_part_2.ipynb
# -rw-r--r--   1 sandeepmakwana  staff    32302 Dec 30  2022 09_Statistics_part_1.ipynb
# -rw-r--r--   1 sandeepmakwana  staff     7382 Feb 12  2023 10_Statistics_part_2.ipynb
# ...

# %%
a=[10,20,30,40]
b=[80,160,200,500] 
matplotlib.pyplot.plot(a,b)
matplotlib.pyplot.savefig("xyz.png")
matplotlib.pyplot.show()


import os
cmd = 'ls -l'
os.system(cmd)

# abhi abc.png ko display hoga
print("----"*34)
print("abhi abc.png ko display hoga")

import IPython.display as display
from PIL import Image
display.display(Image.open('xyz.png'))
# Out:
# total 13104
# -rw-r--r--   1 sandeepmakwana  staff     1026 Mar 23  2023 01_importend_topics.txt
# -rw-r--r--@  1 sandeepmakwana  staff    11377 Nov 21 19:26 02_Vector_Operations.ipynb
# -rw-r--r--@  1 sandeepmakwana  staff    19625 Nov 22 20:00 03_Numpy_operations_part_1.ipynb
# -rw-r--r--@  1 sandeepmakwana  staff     7181 Nov 23 08:47 04_Numpy_operations_part_2.ipynb
# -rw-r--r--@  1 sandeepmakwana  staff    12951 Nov 23 09:01 05_Matrix_opreations_part_3.ipynb
# -rw-r--r--@  1 sandeepmakwana  staff    17431 Nov 23 19:39 06_matrix_operations_part_5.ipynb
# -rw-r--r--@  1 sandeepmakwana  staff   762722 Nov 23 20:10 07_Matplotlib_part_1.ipynb
# -rw-r--r--@  1 sandeepmakwana  staff   589739 Nov 30 15:50 08_Matplotlib_part_2.ipynb
# -rw-r--r--   1 sandeepmakwana  staff    32302 Dec 30  2022 09_Statistics_part_1.ipynb
# -rw-r--r--   1 sandeepmakwana  staff     7382 Feb 12  2023 10_Statistics_part_2.ipynb
# ...

# %%
a=[10,20,30,40]
b=[80,160,200,500]

matplotlib.pyplot.plot(a,b,color="k")
matplotlib.pyplot.savefig("abc2.png")
matplotlib.pyplot.show()

# %%
# YOU CAN ALSO PASS THE COLOR CODE IN PLOT
a=[10,20,30,40]
b=[80,160,200,500]

matplotlib.pyplot.plot(a,b,color="#ffaabb") # 0-f it accepted the hxagonal value
matplotlib.pyplot.savefig("abc2.png")
matplotlib.pyplot.show()

# %%
a=[10,20,30,40]
b=[80,160,200,500]

matplotlib.pyplot.plot(a,b,color="#11aabb") # 0-f it accepted the hxagonal value
matplotlib.pyplot.savefig("abc2.png")
matplotlib.pyplot.show()

# %%
# it can also accept the RGB values 

a=[10,20,30,40]
b=[80,160,200,500]

# matplotlib.pyplot.plot(a,b,color=(80,80,80)) # value should be in range of 0 to 1
matplotlib.pyplot.plot(a,b,color=(.8,.8,.8))
# matplotlib.pyplot.plot(a,b,color=(.1,.2,.5))
matplotlib.pyplot.savefig("abc2.png")
matplotlib.pyplot.show()

# %%
a=[10,20,30,40]
b=[80,160,200,500]

matplotlib.pyplot.plot(a,b,'--',color="#11aabb") # --,-.,:,
matplotlib.pyplot.savefig("abc2.png")
matplotlib.pyplot.show()

# %%
a=[10,20,30,40]
b=[80,160,200,500]

matplotlib.pyplot.plot(a,b,'-.',color="#11aabb") # --,-.,:,
matplotlib.pyplot.savefig("abc2.png")
matplotlib.pyplot.show()

# %%
a=[10,20,30,40]
b=[80,160,200,500]

matplotlib.pyplot.plot(a,b,':',color="#11aabb") # --,-.,:,
matplotlib.pyplot.savefig("abc2.png")
matplotlib.pyplot.show()

# %%
a=[10,20,30,40]
b=[80,160,200,500]

matplotlib.pyplot.plot(a,b,'-1',color="#11aabb") # --,-.,:,-1
matplotlib.pyplot.savefig("abc2.png")
matplotlib.pyplot.show()

# %%
a=[10,20,30,40]
b=[80,160,200,500]

matplotlib.pyplot.plot(a,b,'-<',color="#11aabb") # --,-.,:,-1
matplotlib.pyplot.savefig("abc2.png")
matplotlib.pyplot.show()

# %%
a=[10,20,30,40]
b=[80,160,200,500]

matplotlib.pyplot.plot(a,b,'->',color="#11aabb") # --,-.,:,-1
matplotlib.pyplot.savefig("abc2.png")
matplotlib.pyplot.show()

# %%
a=[10,20,30,40]
b=[80,160,200,500]

matplotlib.pyplot.plot(a,b,'-v',color="#11aabb") # --,-.,:,-1
matplotlib.pyplot.savefig("abc2.png")
matplotlib.pyplot.show()

# %%
a=[10,20,30,40]
b=[80,160,200,500]

matplotlib.pyplot.plot(a,b,'-^',color="#11aabb") # --,-.,:,-1
matplotlib.pyplot.savefig("abc2.png")
matplotlib.pyplot.show()

# %% [markdown]
# # the way of writing linestyle

# %%
a=[10,20,30,40]
b=[80,160,200,500]
# 1,2,3,4,s,p,h,<,>,v,^.*,+,
matplotlib.pyplot.plot(a,b,linestyle=':',color="#11aabb") # --,-.,:,-1
matplotlib.pyplot.savefig("abc2.png")
matplotlib.pyplot.show()

# %% [markdown]
# # historgram

# %%
import matplotlib.pyplot
import numpy
a=numpy.random.randint(20,100,size=15)
print(a)
matplotlib.pyplot.hist(a,15)
matplotlib.pyplot.show()
# Out:
# [22 35 42 36 23 41 34 35 97 43 24 57 34 50 90]

# %%
a=(10,15,25,50)
captions =("Pizza","Burger","Coke","Finger chips")
matplotlib.pyplot.pie(a,labels=captions)
matplotlib.pyplot.show()

# %%
a=(10,15,25,50)
captions =("Pizza","Burger","Coke","Finger chips")
matplotlib.pyplot.pie(a,labels=captions,explode=(.1,.1,.1,.4))
matplotlib.pyplot.show()

# %% [markdown]
# # Scatter

# %%
a=numpy.random.randint(100,size=50)
b=numpy.random.randint(100,200,size=50)
print(a)
print(b)
matplotlib.pyplot.scatter(a,b)
matplotlib.pyplot.show()
# Out:
# [23 89 71 32 33 29 10 13 69 86 51 84 49 92 89 37 41 95 91 16 64 65 49 71
#  85 98  5 43  8 11 27 95 77 24 28  2 59 26 76 64 22 83 90 86 88 58 73 97
#  29 72]
# [144 146 134 107 107 101 157 105 194 185 188 195 152 136 143 158 159 162
#  168 179 119 158 182 178 197 187 156 143 107 161 146 157 160 128 191 179
#  153 188 131 185 141 140 129 149 190 139 144 181 167 181]

# %%
a=[10,20,30,40,50,56,5]
matplotlib.pyplot.plot(a,color='red')
matplotlib.pyplot.show()

# %%
a=[10,20,30,40,50,56,5]
b=matplotlib.pyplot.plot(a,color='red') # big mistake
print(type(b))
# print(b)
matplotlib.pyplot.show()
# Out:
# <class 'list'>
# ...

# %%
a=[10,20,30,40,50,56,5]
b=matplotlib.pyplot.plot(a,color='red') # big mistake
# print(type(b))
c,=matplotlib.pyplot.plot(a,color='red') # right hai
print(type(c))
matplotlib.pyplot.show()
# Out:
# <class 'matplotlib.lines.Line2D'>

# %%
#Esa functions hota hai color wala


def dosomething(x):
    if x>50: return "great"
    else: return 55
    
    
    
a=dosomething(10)
print(type(a))
b=dosomething(500)
print(type(b))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# ---

# %% [markdown]
# # OOPM me karte hai isko

# %%
 
a=[10,20,30,40,45,56,5]
b,=matplotlib.pyplot.plot(a,color="red")
matplotlib.pyplot.show()

c,=matplotlib.pyplot.plot(a)
c.set_color('blue')
matplotlib.pyplot.show()

d,=matplotlib.pyplot.plot(a)
d.set_color('#ffaabb')
matplotlib.pyplot.show()

e,=matplotlib.pyplot.plot(a)
e.set_color('#000000')
matplotlib.pyplot.show()
