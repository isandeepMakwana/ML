# %%
import matplotlib.pyplot

# %%
a=[10,20,30,40]  # show the x - axis
b=[80,160,200,500] # show the Y - axis
matplotlib.pyplot.plot(a,b) # mean by (a,b)
matplotlib.pyplot.show()

# %% [markdown]
# # save fig
# # and also yee kha pe work karta hai
# # show ke baad
# # or show ke phale
# ## Focus on it

# %%
a=[10,20,30,40]
b=[80,160,200,500] 
matplotlib.pyplot.plot(a,b)
matplotlib.pyplot.show()
matplotlib.pyplot.savefig("xyz.png")

# %%
import os
cmd = 'ls -l'
os.system(cmd)

# check the xyz.png is not display anything becouse of yee show se phale hai 
# kuch write nhi huva xyz.png me


import IPython.display as display
from PIL import Image
display.display(Image.open('xyz.png'))
# Out:
# total 1432
# -rw-r--r--@  1 sandeepmakwana  staff    9054 Jun 18 23:10 Lecture 2 (Vector Operations).ipynb
# -rw-r--r--@  1 sandeepmakwana  staff   16261 May 28 18:12 Lecture 3 (Numpy operations part 1).ipynb
# -rw-r--r--@  1 sandeepmakwana  staff    6642 May 28 21:54 Lecture 4 (Numpy operations part 2).ipynb
# -rw-r--r--@  1 sandeepmakwana  staff   12635 May 30 15:11 Lecture 5(matrix operations part 3).ipynb
# -rw-r--r--@  1 sandeepmakwana  staff   14763 May 30 21:54 Lecture 6 (matrix operations part 5).ipynb
# -rw-r--r--   1 sandeepmakwana  staff  420421 Jun 11 22:32 Lecture 7 (matplotlib part 1).ipynb
# -rw-r--r--   1 sandeepmakwana  staff  198191 Jun 20 12:02 Lecture 8 (Matplotlib part 2).ipynb
# -rw-r--r--   1 sandeepmakwana  staff       5 Jun 11 22:34 README.md
# -rw-r--r--@  1 sandeepmakwana  staff    8959 Jun 17 09:14 abc.png
# -rw-r--r--   1 sandeepmakwana  staff    9103 Jun 20 11:58 abc2.png
# -rw-r--r--@  1 sandeepmakwana  staff     224 May 28 21:54 amat.npy
# drwxr-xr-x  11 sandeepmakwana  staff     352 Jun 11 22:42 ml_pdfs
# -rw-r--r--@  1 sandeepmakwana  staff     100 May 28 21:54 saveTxt
# -rw-r--r--@  1 sandeepmakwana  staff    1257 Jun 20 18:44 xyz.png
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=432x288>

# %%
a=[10,20,30,40]
b=[80,160,200,500] 
matplotlib.pyplot.plot(a,b)
matplotlib.pyplot.savefig("xyz.png")
matplotlib.pyplot.show()


import os
cmd = 'ls -l'
os.system(cmd)

# abhi abc.png ko display hoga
print("----"*34)
print("abhi abc.png ko display hoga")

import IPython.display as display
from PIL import Image
display.display(Image.open('xyz.png'))
# Out:
# total 1448
# -rw-r--r--@  1 sandeepmakwana  staff    9054 Jun 18 23:10 Lecture 2 (Vector Operations).ipynb
# -rw-r--r--@  1 sandeepmakwana  staff   16261 May 28 18:12 Lecture 3 (Numpy operations part 1).ipynb
# -rw-r--r--@  1 sandeepmakwana  staff    6642 May 28 21:54 Lecture 4 (Numpy operations part 2).ipynb
# -rw-r--r--@  1 sandeepmakwana  staff   12635 May 30 15:11 Lecture 5(matrix operations part 3).ipynb
# -rw-r--r--@  1 sandeepmakwana  staff   14763 May 30 21:54 Lecture 6 (matrix operations part 5).ipynb
# -rw-r--r--   1 sandeepmakwana  staff  420421 Jun 11 22:32 Lecture 7 (matplotlib part 1).ipynb
# -rw-r--r--   1 sandeepmakwana  staff  198191 Jun 20 12:02 Lecture 8 (Matplotlib part 2).ipynb
# -rw-r--r--   1 sandeepmakwana  staff       5 Jun 11 22:34 README.md
# -rw-r--r--@  1 sandeepmakwana  staff    8959 Jun 17 09:14 abc.png
# -rw-r--r--   1 sandeepmakwana  staff    9103 Jun 20 11:58 abc2.png
# -rw-r--r--@  1 sandeepmakwana  staff     224 May 28 21:54 amat.npy
# drwxr-xr-x  11 sandeepmakwana  staff     352 Jun 11 22:42 ml_pdfs
# -rw-r--r--@  1 sandeepmakwana  staff     100 May 28 21:54 saveTxt
# -rw-r--r--@  1 sandeepmakwana  staff    8959 Jun 20 18:44 xyz.png
# ----------------------------------------------------------------------------------------------------------------------------------------
# abhi abc.png ko display hoga
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=432x288>

# %%
a=[10,20,30,40]
b=[80,160,200,500]

matplotlib.pyplot.plot(a,b,color="k")
matplotlib.pyplot.savefig("abc2.png")
matplotlib.pyplot.show()

# %%
# YOU CAN ALSO PASS THE COLOR CODE IN PLOT
a=[10,20,30,40]
b=[80,160,200,500]

matplotlib.pyplot.plot(a,b,color="#ffaabb") # 0-f it accepted the hxagonal value
matplotlib.pyplot.savefig("abc2.png")
matplotlib.pyplot.show()

# %%
a=[10,20,30,40]
b=[80,160,200,500]

matplotlib.pyplot.plot(a,b,color="#11aabb") # 0-f it accepted the hxagonal value
matplotlib.pyplot.savefig("abc2.png")
matplotlib.pyplot.show()

# %%
# it can also accept the RGB values 

a=[10,20,30,40]
b=[80,160,200,500]

# matplotlib.pyplot.plot(a,b,color=(80,80,80)) # value should be in range of 0 to 1
matplotlib.pyplot.plot(a,b,color=(.8,.8,.8))
# matplotlib.pyplot.plot(a,b,color=(.1,.2,.5))
matplotlib.pyplot.savefig("abc2.png")
matplotlib.pyplot.show()

# %%
a=[10,20,30,40]
b=[80,160,200,500]

matplotlib.pyplot.plot(a,b,'--',color="#11aabb") # --,-.,:,
matplotlib.pyplot.savefig("abc2.png")
matplotlib.pyplot.show()

# %%
a=[10,20,30,40]
b=[80,160,200,500]

matplotlib.pyplot.plot(a,b,'-.',color="#11aabb") # --,-.,:,
matplotlib.pyplot.savefig("abc2.png")
matplotlib.pyplot.show()

# %%
a=[10,20,30,40]
b=[80,160,200,500]

matplotlib.pyplot.plot(a,b,':',color="#11aabb") # --,-.,:,
matplotlib.pyplot.savefig("abc2.png")
matplotlib.pyplot.show()

# %%
a=[10,20,30,40]
b=[80,160,200,500]

matplotlib.pyplot.plot(a,b,'-1',color="#11aabb") # --,-.,:,-1
matplotlib.pyplot.savefig("abc2.png")
matplotlib.pyplot.show()

# %%
a=[10,20,30,40]
b=[80,160,200,500]

matplotlib.pyplot.plot(a,b,'-<',color="#11aabb") # --,-.,:,-1
matplotlib.pyplot.savefig("abc2.png")
matplotlib.pyplot.show()

# %%
a=[10,20,30,40]
b=[80,160,200,500]

matplotlib.pyplot.plot(a,b,'->',color="#11aabb") # --,-.,:,-1
matplotlib.pyplot.savefig("abc2.png")
matplotlib.pyplot.show()

# %%
a=[10,20,30,40]
b=[80,160,200,500]

matplotlib.pyplot.plot(a,b,'-v',color="#11aabb") # --,-.,:,-1
matplotlib.pyplot.savefig("abc2.png")
matplotlib.pyplot.show()

# %%
a=[10,20,30,40]
b=[80,160,200,500]

matplotlib.pyplot.plot(a,b,'-^',color="#11aabb") # --,-.,:,-1
matplotlib.pyplot.savefig("abc2.png")
matplotlib.pyplot.show()

# %% [markdown]
# # the way of writing linestyle

# %%
a=[10,20,30,40]
b=[80,160,200,500]
# 1,2,3,4,s,p,h,<,>,v,^.*,+,
matplotlib.pyplot.plot(a,b,linestyle=':',color="#11aabb") # --,-.,:,-1
matplotlib.pyplot.savefig("abc2.png")
matplotlib.pyplot.show()

# %% [markdown]
# # historgram

# %%
import matplotlib.pyplot
import numpy
a=numpy.random.randint(20,100,size=15)
print(a)
matplotlib.pyplot.hist(a,15)
matplotlib.pyplot.show()
# Out:
# [75 21 88 36 85 30 67 99 33 59 25 36 57 98 62]

# %%
a=(10,15,25,50)
captions =("Pizza","Burger","Coke","Finger chips")
matplotlib.pyplot.pie(a,labels=captions)
matplotlib.pyplot.show()

# %%
a=(10,15,25,50)
captions =("Pizza","Burger","Coke","Finger chips")
matplotlib.pyplot.pie(a,labels=captions,explode=(.1,.1,.1,.4))
matplotlib.pyplot.show()

# %% [markdown]
# # Scatter

# %%
a=numpy.random.randint(100,size=50)
b=numpy.random.randint(100,200,size=50)
matplotlib.pyplot.scatter(a,b)
matplotlib.pyplot.show()

# %%
a=[10,20,30,40,50,56,5]
matplotlib.pyplot.plot(a,color='red')
matplotlib.pyplot.show()

# %%
a=[10,20,30,40,50,56,5]
b=matplotlib.pyplot.plot(a,color='red') # big mistake
print(type(b))
matplotlib.pyplot.show()
# Out:
# <class 'list'>

# %%
a=[10,20,30,40,50,56,5]
b=matplotlib.pyplot.plot(a,color='red') # big mistake
# print(type(b))
c,=matplotlib.pyplot.plot(a,color='red') # right hai
print(type(c))
matplotlib.pyplot.show()
# Out:
# <class 'matplotlib.lines.Line2D'>

# %%
#Esa functions hota hai color wala


def dosomething(x):
    if x>50: return "great"
    else: return 55
    
    
    
a=dosomething(10)
print(type(a))
b=dosomething(500)
print(type(b))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# # oops me karte hai isko

# %%
 
a=[10,20,30,40,45,56,5]
b,=matplotlib.pyplot.plot(a,color="red")
matplotlib.pyplot.show()

c,=matplotlib.pyplot.plot(a)
c.set_color('blue')
matplotlib.pyplot.show()

d,=matplotlib.pyplot.plot(a)
d.set_color('#ffaabb')
matplotlib.pyplot.show()

e,=matplotlib.pyplot.plot(a)
e.set_color('#000000')
matplotlib.pyplot.show()
