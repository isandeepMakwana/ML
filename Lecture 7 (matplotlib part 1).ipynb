# %%
# Install 
# pip install matplotlib
 
# upgrade the version of lib
# python -m pip install -U matplotlib

# %%
import matplotlib.pyplot
data = [10,20,30,5,60]
matplotlib.pyplot.plot(data)
matplotlib.pyplot.show()

# %%
data =[]
for x in range(10):
    data.append(x**3)
print(data)
matplotlib.pyplot.plot(data)
matplotlib.pyplot.show()
# Out:
# [0, 1, 8, 27, 64, 125, 216, 343, 512, 729]

# %%
import numpy
import matplotlib.pyplot

a=numpy.random.randint(50,size=10)
b=numpy.random.randint(50,size=15)
matplotlib.pyplot.plot(a)
matplotlib.pyplot.plot(b)
print(a)
print(b)
matplotlib.pyplot.show()
# Out:
# [ 9 32  3 24 47 49 45 49 43 24]
# [13 39 26  5 21 47  2 17 18 38 37  5 20 28  2]

# %%
a= numpy.random.randint(50,size=10)
# b= numpy.random.randint(100,size=15)
b= numpy.random.randint(100,size=10)
matplotlib.pyplot.plot(a,b) # can't work with differnet size , so the element size should be same
print(a)
print(b)
matplotlib.pyplot.show()
# Out:
# [24 37 48  1 48 38 14 45 28 47]
# [10 45 11 67 31 86  0 94 68 62]

# %%
a = numpy.random.randint(50,size=10)
b = numpy.random.randint(100,150,size=10)
matplotlib.pyplot.plot(a,b)
print(a)
print(b)

matplotlib.pyplot.show()
c=[]
for x in a: c.append(x)
for x in b: c.append(x)
print(c)
matplotlib.pyplot.plot(c)
matplotlib.pyplot.show()
# Out:
# [23 40 48 10 27  7 46  1 44 14]
# [109 132 122 107 113 143 128 148 145 136]
# [23, 40, 48, 10, 27, 7, 46, 1, 44, 14, 109, 132, 122, 107, 113, 143, 128, 148, 145, 136]

# %%
data=numpy.matrix(((10,20,30,40),(15,25,35,45)))
print('data\n',data)
matplotlib.pyplot.plot(data)
matplotlib.pyplot.show()

print("working 10-15 20-35")
print("yee column wasie show kar rha hai")
# Out:
# data
#  [[10 20 30 40]
#  [15 25 35 45]]
# working 10-15 20-35
# yee column wasie show kar rha hai

# %%
# row wasie show karna ho to 

data=numpy.matrix(((10,20,30,40),(15,25,35,50)))
print('data\n',data)
print('row wasie show')
matplotlib.pyplot.plot(data.transpose())
matplotlib.pyplot.show()
# Out:
# data
#  [[10 20 30 40]
#  [15 25 35 50]]
# row wasie show

# %%
data1=numpy.matrix(((10,20,30,40),(15,25,35,50)))
print('data1\n',data1)
matplotlib.pyplot.plot(data1.transpose())
matplotlib.pyplot.show()
data2=numpy.random.randint(50,size=(4,3)).transpose()
print('data2\n',data2)
matplotlib.pyplot.plot(data2)
matplotlib.pyplot.show()
# Out:
# data1
#  [[10 20 30 40]
#  [15 25 35 50]]
# data2
#  [[40 10 31 23]
#  [ 7 30 23 45]
#  [47 48 32 25]]

# %% [markdown]
# # intersting kuch banate hai

# %%
sales=numpy.random.randint(50000,size=12)
print(sales)
matplotlib.pyplot.plot(sales)
# grid 
matplotlib.pyplot.grid(True)
matplotlib.pyplot.show()
# Out:
# [19735 41050 37444 25317 17258 43593 43739 38808 33743  7043 19967 43209]

# %%
#lable added
sales=numpy.random.randint(50000,size=12)
print(sales)
matplotlib.pyplot.plot(sales)
# grid 
matplotlib.pyplot.grid(True)
# lable 
matplotlib.pyplot.xlabel("Months")
matplotlib.pyplot.ylabel("Sales")
matplotlib.pyplot.show()
# Out:
# [ 9009 46516 34137 48237 44168 30174 43710 10319 16834  8705  8296   521]

# %%
# month added in x axies
sales=numpy.random.randint(50000,size=12)
print(sales)
matplotlib.pyplot.plot(sales)
# grid 
matplotlib.pyplot.grid(True)
# lable 
matplotlib.pyplot.xlabel("Months")
matplotlib.pyplot.ylabel("Sales")

# xticks
matplotlib.pyplot.xticks(range(12),["a","b","c","d","e","f","g","h","j","k","l","p"])
# matplotlib.pyplot.xticks(range(12),range(1,13))
matplotlib.pyplot.show()
# Out:
# [26297 26062 21652 27014 48785 43812  1183 10474 25532  9569  3302 46674]

# %%
# month added in x axies
sales=numpy.random.randint(50000,size=12)
print(sales)
matplotlib.pyplot.plot(sales)
# grid 
matplotlib.pyplot.grid(True)
# lable 
matplotlib.pyplot.xlabel("Months")
matplotlib.pyplot.ylabel("Sales")

# xticks
# matplotlib.pyplot.xticks(range(12),["a","b","c","d","e","f","g","h","j","k","l","p"])
matplotlib.pyplot.xticks(range(12),range(1,13))
matplotlib.pyplot.show()
# Out:
# [22992 48303 10308 47492 37334 18513 11102 36228 33876  4749 29204 13353]

# %%
# set the title
# month added in x axies
sales=numpy.random.randint(50000,size=12)
print(sales)
matplotlib.pyplot.plot(sales)
# grid 
matplotlib.pyplot.grid(True)
# lable 
matplotlib.pyplot.xlabel("Months")
matplotlib.pyplot.ylabel("Sales")

# xticks
# matplotlib.pyplot.xticks(range(12),["a","b","c","d","e","f","g","h","j","k","l","p"])
matplotlib.pyplot.xticks(range(12),range(1,13))
matplotlib.pyplot.title("sales Predictions for year 2022")
matplotlib.pyplot.show()
# Out:
# [41695 23440 34848 21303 23804 31299 32376 18221 49159 21404 21007 21079]

# %% [markdown]
# # #Another Example :
# # Sales Predictions for year 2021 / 2022

# %%
sales2021 = numpy.random.randint(500000,size=12)
sales2022 = numpy.random.randint(500000,size=12)
print('sales2021\n',sales2021)
print('sales2022\n',sales2022)
matplotlib.pyplot.plot(sales2021,color='r')
matplotlib.pyplot.plot(sales2022,color='g')
matplotlib.pyplot.xlabel("Months")
matplotlib.pyplot.ylabel("Sales")
matplotlib.pyplot.grid(True)
matplotlib.pyplot.title("Sales Predictions for Year 2021 / 2022")
matplotlib.pyplot.show()
# Out:
# sales2021
#  [ 14892 478580 425392 431646  28971 488225 470010 470312  51268 468346
#   26090 352466]
# sales2022
#  [327913 103020 467995    638 152457 282289 407326 343855 130798 398829
#  499979 116443]

# %%
# identify which line is sales21 and 22
sales2021 = numpy.random.randint(500000,size=12)
sales2022 = numpy.random.randint(500000,size=12)
print('sales2021\n',sales2021)
print('sales2022\n',sales2022)
matplotlib.pyplot.plot(sales2021,color='r',label="2021")
matplotlib.pyplot.plot(sales2022,color='g',label="2022")
matplotlib.pyplot.xlabel("Months")
matplotlib.pyplot.ylabel("Sales")
matplotlib.pyplot.grid(True)
matplotlib.pyplot.legend()
matplotlib.pyplot.xticks(range(12),range(1,13))
matplotlib.pyplot.title("Sales Predictions for Year 2021 / 2022")
matplotlib.pyplot.show()
# Out:
# sales2021
#  [153268 108805 136606 258520 218636  90038 175887 173165 452193 382516
#    9071 475239]
# sales2022
#  [119513 212165 475324 348493 320013 155913 424570  46176 417787 465530
#   30088  43842]

# %%
# more opetiosn
sales2021 = numpy.random.randint(500000,size=12)
sales2022 = numpy.random.randint(500000,size=12)
print('sales2021\n',sales2021)
print('sales2022\n',sales2022)
matplotlib.pyplot.plot(sales2021,color='r',label="2021")
matplotlib.pyplot.plot(sales2022,color='g',label="2022")
matplotlib.pyplot.xlabel("Months")
matplotlib.pyplot.ylabel("Sales")
matplotlib.pyplot.grid(True)
# matplotlib.pyplot.legend()
# matplotlib.pyplot.legend(loc="best")
matplotlib.pyplot.legend(loc="upper left")
matplotlib.pyplot.xticks(range(12),range(1,13))
matplotlib.pyplot.title("Sales Predictions for Year 2021 / 2022")
matplotlib.pyplot.show()
# Out:
# sales2021
#  [438698 420103 448718 401927 229525 210649 134480 123286 446801 313036
#   27927 246021]
# sales2022
#  [402866 257698  88144 248190  15606 207564  97872  79848 481075 280573
#  152185 481808]
